# %% [markdown]
# # 1. Setup

# %% [markdown]
# ### 1.1 Install Dependencies

# %%
# pip install tensorflow==2.11.0

# %%
# pip install tensorflow-gpu

# %%
# pip install opencv-python

# %%
# pip install matplotlib

# %% [markdown]
# ### 1.2 Import Libraries

# %%
import os
import cv2
import sys
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
# Import metric calculations
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten

# %% [markdown]
# ### 1.3 Check GPU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.test.is_built_with_cuda()
# Out:
# False

# %%
print("Number of GPUs available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Number of GPUs available:  0

# %%
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
sys.version
# Out:
# '3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# ### 1.4 Create Folders

# %%
# set all paths
Pos_path = os.path.join('data', 'positive')
Neg_path = os.path.join('data', 'negative')
Anc_path = os.path.join('data', 'anchor')

# %%
# # make the directories, ones we create this and then comment it out
# os.makedirs(Pos_path)
# os.makedirs(Neg_path)
# os.makedirs(Anc_path)

# %% [markdown]
# # 2. Collect Positives and Anchors

# %% [markdown]
# ### 2.1 Unzip Labelled Faces from given dataset

# %%
# # move Images to the following directories data/negatives
# path = '/home/sangramdh/data/data/'
# for directory in os.listdir(path):
#     for file in os.listdir(os.path.join(path, directory)):
#         ex_path = os.path.join(path, directory, file)
#         new_path = os.path.join(Neg_path, file)
#         os.replace(ex_path, new_path)

# %% [markdown]
# ### 2.2 Collect Positive and Anchor Classes

# %%
# universal unique identification
import uuid

# %%
os.path.join(Neg_path, '{}.jpg'.format(uuid.uuid1()))
# Out:
# 'data\\negative\\5ebe00a8-10f9-11ef-8e5e-7c7a9138ecfc.jpg'

# %%
# open webcam for collect images
cap = cv2.VideoCapture(0)
while cap.isOpened(): 
    ret, frame = cap.read()
   
    # cut frame in required size
    frame = frame[120:120+250,200:200+250, :]
    
    # for collecting anchor images press "a"
    if cv2.waitKey(1) & 0XFF == ord('a'):
        # create the pathq
        imgname = os.path.join(Anc_path, '{}.jpg'.format(uuid.uuid1()))
        # write anchor images
        cv2.imwrite(imgname, frame)
    
    # for collecting anchor images press "p"
    if cv2.waitKey(1) & 0XFF == ord('p'):
        imgname = os.path.join(Pos_path, '{}.jpg'.format(uuid.uuid1()))
        # write positive images
        cv2.imwrite(imgname, frame)
    
    # show image
    cv2.imshow('Image Collection', frame)
    
    # come out of camera
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
frame.shape
# Out:
# (250, 250, 3)

# %%
plt.imshow(frame)

# %% [markdown]
# ### 2.3 Data Augmentation

# %%
# Augmentation function

# %%
# def data_aug(img):
#     data = []
#     for i in range(9):
#         img = tf.image.stateless_random_brightness(img, max_delta=0.02, seed=(1,2))
#         img = tf.image.stateless_random_contrast(img, lower=0.6, upper=1, seed=(1,3))
#         # img = tf.image.stateless_random_crop(img, size=(20,20,3), seed=(1,2))
#         img = tf.image.stateless_random_flip_left_right(img, seed=(np.random.randint(100),np.random.randint(100)))
#         img = tf.image.stateless_random_jpeg_quality(img, min_jpeg_quality=90, max_jpeg_quality=100, seed=(np.random.randint(100),np.random.randint(100)))
#         img = tf.image.stateless_random_saturation(img, lower=0.9,upper=1, seed=(np.random.randint(100),np.random.randint(100)))
            
#         data.append(img)
    
#     return data

# %%
# list the directiory for see how many images we have
import glob

path = r'D:\My project\face_reco\app\training\data\anchor\*'

res = glob.glob(path)
len(res)
# Out:
# 6

# %%
# img_path = os.path.join(Anc_path, r'0ae4dc23-10f5-11ef-ad36-7c7a9138ecfc.jpg')
# img = cv2.imread(img_path)
# augmented_images = data_aug(img)

# for image in augmented_images:
#     cv2.imwrite(os.path.join(Anc_path, '{}.jpg'.format(uuid.uuid1), image.numpy()))

# %%
# for file_name in os.listdir(os.path.join(Pos_path)):
#     img_path = os.path.join(Pos_path, file_name)
#     img = cv2.imread(img_path)
#     augmented_images = data_aug(img) 
    
#     for image in augmented_images:
#         cv2.imwrite(os.path.join(Pos_path, '{}.jpg'.format(uuid.uuid1())), image.numpy())

# %% [markdown]
# # 3. Load and Preprocess Images

# %% [markdown]
# ### 3.1 Get Image Directories

# %%
anchor = tf.data.Dataset.list_files(Anc_path+'/*.jpg').take(6)
positive = tf.data.Dataset.list_files(Pos_path+'/*.jpg').take(10)
negative = tf.data.Dataset.list_files(Neg_path+'/*.jpg').take(10)

# %%
dir_test = positive.as_numpy_iterator()

# %%
print(dir_test.next())
# Out:
# b'data\\positive\\e4512879-110b-11ef-a2dc-7c7a9138ecfc.jpg'

# %% [markdown]
# ### 3.2 Preprocessing - Scale and Resize

# %%
def preprocess(file_path):
    # read image from file path
    raw_img = tf.io.read_file(file_path)
    # image load
    img = tf.io.decode_jpeg(raw_img)
    # get required size
    img = tf.image.resize(img, (105, 105))
    # normalize image b/w 0 and 1
    img = img / 255.0
    return img

# %%
img = preprocess(r'D:\My project\face_reco\app\0ae4dc23-10f5-11ef-ad36-7c7a9138ecfc.jpg')

# %%
img.numpy().max()
# Out:
# 1.0

# %% [markdown]
# ### 3.3 Create Labelled Dataset

# %%
# positive => 1,1,1,1,1
# negative => 0,0,0,0,0

positives = tf.data.Dataset.zip((anchor, positive, tf.data.Dataset.from_tensor_slices(tf.ones(len(anchor)))))
negatives = tf.data.Dataset.zip((anchor, negative, tf.data.Dataset.from_tensor_slices(tf.zeros(len(anchor)))))
data = positives.concatenate(negatives)

# %%
data
# Out:
# <ConcatenateDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>

# %%
samples = data.as_numpy_iterator()
samples

# %%
example = samples.next()
example
# Out:
# (b'data\\anchor\\1a422949-10f5-11ef-9697-7c7a9138ecfc.jpg',
#  b'data\\negative\\Ashutosh_YT477_30.jpg',
#  0.0)

# %% [markdown]
# ### 3.4 Build Train and Test Partition

# %%
def preprocess_twin(input_img, validation_img, label):
    return(preprocess(input_img), preprocess(validation_img), label)

# %%
resu = preprocess_twin(*example)

# %%
resu[1] # resu[0], resu[2]
# Out:
# <tf.Tensor: shape=(105, 105, 3), dtype=float32, numpy=
# array([[[0.6045418 , 0.6241496 , 0.7792117 ],
#         [0.61054426, 0.6297919 , 0.7868347 ],
#         [0.6114846 , 0.63529414, 0.7947179 ],
#         ...,
#         [0.3644657 , 0.34597775, 0.37396914],
#         [0.37955177, 0.36778706, 0.39523804],
#         [0.35938388, 0.34761918, 0.37507015]],
#
#        [[0.9817927 , 0.9890756 , 0.98487395],
#         [0.9565425 , 0.9747699 , 0.985174  ],
#         [0.93485385, 0.96330523, 0.98465383],
#         ...,
#         [0.36414644, 0.37030837, 0.4173672 ],
#         [0.37675074, 0.37675074, 0.4238096 ],
#         [0.38561437, 0.38561437, 0.4326732 ]],
#
#        [[0.66190475, 0.6658263 , 0.8478992 ],
#         [0.664986  , 0.67366946, 0.8361345 ],
#         [0.667507  , 0.6632253 , 0.8294318 ],
#         ...,
#         [0.40458176, 0.42026803, 0.46732685],
#         [0.43137255, 0.4392157 , 0.49019608],
#         [0.44031623, 0.43639466, 0.49129662]],
#
#        ...,
#
#        [[0.39469802, 0.3358745 , 0.6064627 ],
#         [0.33411345, 0.28313306, 0.5537213 ],
#         [0.3369939 , 0.27817038, 0.5409154 ],
#         ...,
#         [0.26684722, 0.22370997, 0.4825335 ],
#         [0.304042  , 0.24521852, 0.4687479 ],
#         [0.21092458, 0.15602261, 0.3481795 ]],
#
#        [[0.34201598, 0.28319246, 0.5459376 ],
#         [0.371467  , 0.31264347, 0.5753886 ],
#         [0.35019976, 0.29137623, 0.5541214 ],
#         ...,
#         [0.29871958, 0.2438176 , 0.47675112],
#         [0.300021  , 0.22943275, 0.42443013],
#         [0.11840275, 0.05173608, 0.21644197]],
#
#        [[0.34005603, 0.2812325 , 0.5518207 ],
#         [0.36086446, 0.30204093, 0.5726292 ],
#         [0.36720702, 0.30838346, 0.57112855],
#         ...,
#         [0.31740695, 0.2633456 , 0.47202936],
#         [0.24275671, 0.17637008, 0.33967575],
#         [0.06750632, 0.01652593, 0.12632985]]], dtype=float32)>

# %%
plt.imshow(resu[1])

# %%
# DataLoader pipeline
data = data.map(preprocess_twin)
data = data.cache()
data = data.shuffle(buffer_size=1000)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 2
#       1 # DataLoader pipeline
# ----> 2 data = data.map(preprocess_twin)
#       3 data = data.cache()
#       4 data = data.shuffle(buffer_size=1000)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2294, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2291   if deterministic is not None and not DEBUG_MODE:
#    2292     warnings.warn("The `deterministic` argument has no effect unless the "
#    2293                   "`num_parallel_calls` argument is specified.")
# -> 2294   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2295 else:
#    2296   return ParallelMapDataset(
#    2297       self,
#    2298       map_func,
#    (...)
#    2301       preserve_cardinality=True,
#    2302       name=name)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5499, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5497 self._use_inter_op_parallelism = use_inter_op_parallelism
#    5498 self._preserve_cardinality = preserve_cardinality
# -> 5499 self._map_func = structured_function.StructuredFunctionWrapper(
#    5500     map_func,
#    5501     self._transformation_name(),
#    5502     dataset=input_dataset,
#    5503     use_legacy_function=use_legacy_function)
#    5504 self._name = name
#    5505 variant_tensor = gen_dataset_ops.map_dataset(
#    5506     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    5507     self._map_func.function.captured_inputs,
#    (...)
#    5510     preserve_cardinality=self._preserve_cardinality,
#    5511     **self._common_args)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\data\ops\structured_function.py:263, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     256       warnings.warn(
#     257           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     258           "option is set, this option does not apply to tf.data functions. "
#     259           "To force eager execution of tf.data functions, please use "
#     260           "`tf.data.experimental.enable_debug_mode()`.")
#     261     fn_factory = trace_tf_function(defun_kwargs)
# --> 263 self._function = fn_factory()
#     264 # There is no graph to add in eager mode.
#     265 add_to_graph &= not context.executing_eagerly()
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:226, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     217 def get_concrete_function(self, *args, **kwargs):
#     218   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     219
#     220   Args:
#    (...)
#     224       `tf.Tensor` or `tf.TensorSpec`.
#     225   """
# --> 226   concrete_function = self._get_concrete_function_garbage_collected(
#     227       *args, **kwargs)
#     228   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     229   return concrete_function
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:192, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     189   self._function_spec.validate_inputs_with_signature(args, kwargs)
#     191 with self._lock:
# --> 192   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193   seen_names = set()
#     194   captured = object_identity.ObjectIdentitySet(
#     195       concrete_function.graph.internal_captures)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:157, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     154   args = self.input_signature
#     155   kwargs = {}
# --> 157 return self._maybe_define_function(args, kwargs)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:360, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     357   # Only get placeholders for arguments, not captures
#     358   args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
# --> 360 concrete_function = self._create_concrete_function(args, kwargs)
#     362 graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#     363 # Maintain the list of all captures
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:284, in TracingCompiler._create_concrete_function(self, args, kwargs)
#     279 missing_arg_names = [
#     280     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#     281 ]
#     282 arg_names = base_arg_names + missing_arg_names
#     283 concrete_function = monomorphic_function.ConcreteFunction(
# --> 284     func_graph_module.func_graph_from_py_func(
#     285         self._name,
#     286         self._python_function,
#     287         args,
#     288         kwargs,
#     289         None,
#     290         autograph=self._autograph,
#     291         autograph_options=self._autograph_options,
#     292         arg_names=arg_names,
#     293         capture_by_value=self._capture_by_value),
#     294     self._function_attributes,
#     295     spec=self.function_spec,
#     296     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     297     # scope. This is not the default behavior since it gets used in some
#     298     # places (like Keras) where the FuncGraph lives longer than the
#     299     # ConcreteFunction.
#     300     shared_func_graph=False)
#     301 return concrete_function
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\framework\func_graph.py:1283, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1280 else:
#    1281   _, original_func = tf_decorator.unwrap(python_func)
# -> 1283 func_outputs = python_func(*func_args, **func_kwargs)
#    1285 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1286 # TensorArrays and `None`s.
#    1287 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\data\ops\structured_function.py:240, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     234 @eager_function.defun_with_attributes(
#     235     input_signature=structure.get_flat_tensor_specs(
#     236         self._input_structure),
#     237     autograph=False,
#     238     attributes=defun_kwargs)
#     239 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 240   ret = wrapper_helper(*args)
#     241   ret = structure.to_tensor_list(self._output_structure, ret)
#     242   return [ops.convert_to_tensor(t) for t in ret]
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\data\ops\structured_function.py:171, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     169 if not _should_unpack(nested_args):
#     170   nested_args = (nested_args,)
# --> 171 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     172 ret = variable_utils.convert_variables_to_tensors(ret)
#     173 if _should_pack(ret):
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\autograph\impl\api.py:692, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
# --> 692     raise e.ag_error_metadata.to_exception(e)
#     693   else:
#     694     raise
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\autograph\impl\api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_file4_hgyhka.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf__preprocess_twin(input_img, validation_img, label)
#      10 try:
#      11     do_return = True
# ---> 12     retval_ = (ag__.converted_call(ag__.ld(preprocess), (ag__.ld(input_img),), None, fscope), ag__.converted_call(ag__.ld(preprocess), (ag__.ld(validation_img),), None, fscope), ag__.ld(label))
#      13 except:
#      14     do_return = False
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\autograph\impl\api.py:441, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     439     result = converted_f(*effective_args, **kwargs)
#     440   else:
# --> 441     result = converted_f(*effective_args)
#     442 except Exception as e:
#     443   _attach_error_metadata(e, converted_f)
#
# File ~\AppData\Local\Temp\__autograph_generated_file23nl0rlo.py:10, in outer_factory.<locals>.inner_factory.<locals>.tf__preprocess(file_path)
#       8 do_return = False
#       9 retval_ = ag__.UndefinedReturnValue()
# ---> 10 raw_img = ag__.converted_call(ag__.ld(tf).io.read_file, (ag__.ld(file_path),), None, fscope)
#      11 img = ag__.converted_call(ag__.ld(tf).io.decode_jpeg, (ag__.ld(raw_img),), None, fscope)
#      12 img = ag__.converted_call(ag__.ld(tf).image.resize, (ag__.ld(img), (105, 105)), None, fscope)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\ops\io_ops.py:133, in read_file(filename, name)
#      96 @tf_export("io.read_file", v1=["io.read_file", "read_file"])
#      97 def read_file(filename, name=None):
#      98   """Reads the contents of file.
#      99
#     100   This operation returns a tensor with the entire contents of the input
#    (...)
#     131     A tensor of dtype "string", with the file contents.
#     132   """
# --> 133   return gen_io_ops.read_file(filename, name)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\ops\gen_io_ops.py:615, in read_file(filename, name)
#     613     pass  # Add nodes to the TensorFlow graph.
#     614 # Add nodes to the TensorFlow graph.
# --> 615 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     616       "ReadFile", filename=filename, name=name)
#     617 _result = _outputs[:]
#     618 if _execute.must_record_gradient():
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\framework\op_def_library.py:777, in _apply_op_helper(op_type_name, name, **keywords)
#     775 with g.as_default(), ops.name_scope(name) as scope:
#     776   if fallback:
# --> 777     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     778                            keywords, default_type_attr_map, attrs, inputs,
#     779                            input_types)
#     780     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     781                            default_type_attr_map, attrs)
#     782     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File D:\My project\face_reco\face\lib\site-packages\tensorflow\python\framework\op_def_library.py:577, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     574 prefix = ("Input '%s' of '%s' Op has type %s that does not match" %
#     575           (input_name, op_type_name, observed))
#     576 if input_arg.type != types_pb2.DT_INVALID:
# --> 577   raise TypeError(f"{prefix} expected type of "
#     578                   f"{dtypes.as_dtype(input_arg.type).name}.")
#     579 else:
#     580   # Update the maps with the default, if needed.
#     581   k = input_arg.type_attr
#
# TypeError: in user code:
#
#     File "C:\Users\USER\AppData\Local\Temp\ipykernel_3076\3087020015.py", line 2, in preprocess_twin  *
#         return(preprocess(input_img), preprocess(validation_img), label)
#     File "C:\Users\USER\AppData\Local\Temp\ipykernel_3076\4020578498.py", line 3, in preprocess  *
#         raw_img = tf.io.read_file(file_path)
#
#     TypeError: Input 'filename' of 'ReadFile' Op has type float32 that does not match expected type of string.

# %%
len(data)
# Out:
# 10

# %%
da_test = data.as_numpy_iterator()

# %%
test_im = da_test.next()

# %%
plt.imshow(test_im[1])

# %%
test_im[2] # checked label is correct or not
# Out:
# 1.0

# %%
round(len(data)*.7)
# Out:
# 7

# %%
# training data
train_data = data.skip(round(len(data)*.7))
train_data = train_data.batch(16)
train_data = train_data.prefetch(8)

# %%
round(len(data)*.3)
# Out:
# 3

# %%
# testing data
test_data = data.skip(round(len(data)*.7))
test_data = test_data.take(round(len(data)*.3))
test_data = test_data.batch(16)
test_data = test_data.prefetch(8)

# %%
len(test_data)
# Out:
# 1

# %% [markdown]
# # 4. Model Engineering

# %% [markdown]
# ### 4.1 Build Embedding Layer

# %%
inp = Input(shape=(105,105,3), name='input_image')
inp
# Out:
# <KerasTensor: shape=(None, 105, 105, 3) dtype=float32 (created by layer 'input_image')>

# %%
c1 = Conv2D(64, (10,10), activation='relu')(inp)
c1
# Out:
# <KerasTensor: shape=(None, 96, 96, 64) dtype=float32 (created by layer 'conv2d')>

# %%
m1 = MaxPooling2D(64, (2,2), padding='same')(c1)
m1
# Out:
# <KerasTensor: shape=(None, 48, 48, 64) dtype=float32 (created by layer 'max_pooling2d')>

# %%
c2 = Conv2D(128, (7,7), activation='relu')(m1)
c2
# Out:
# <KerasTensor: shape=(None, 42, 42, 128) dtype=float32 (created by layer 'conv2d_1')>

# %%
m2 = MaxPooling2D(64, (2,2), padding='same')(c2)
m2
# Out:
# <KerasTensor: shape=(None, 21, 21, 128) dtype=float32 (created by layer 'max_pooling2d_1')>

# %%
c3 = Conv2D(128, (4,4), activation='relu')(m2)
c3
# Out:
# <KerasTensor: shape=(None, 18, 18, 128) dtype=float32 (created by layer 'conv2d_2')>

# %%
m3 = MaxPooling2D(64, (2,2), padding='same')(c3)
m3
# Out:
# <KerasTensor: shape=(None, 9, 9, 128) dtype=float32 (created by layer 'max_pooling2d_2')>

# %%
c4 = Conv2D(256, (4,4), activation='relu')(m3)
c4
# Out:
# <KerasTensor: shape=(None, 6, 6, 256) dtype=float32 (created by layer 'conv2d_3')>

# %%
f1 = Flatten()(c4)
f1
# Out:
# <KerasTensor: shape=(None, 9216) dtype=float32 (created by layer 'flatten')>

# %%
d1 = Dense(4096, activation='sigmoid')(f1)
d1
# Out:
# <KerasTensor: shape=(None, 4096) dtype=float32 (created by layer 'dense')>

# %%
modl = Model(inputs=[inp], outputs=[d1], name='embedding')
modl

# %%
modl.summary()
# Out:
# Model: "embedding"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 105, 105, 3)]     0
#
#  conv2d (Conv2D)             (None, 96, 96, 64)        19264
#
#  max_pooling2d (MaxPooling2D  (None, 48, 48, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 128)       401536
#
#  max_pooling2d_1 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 18, 18, 128)       262272
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 256)         524544
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
# =================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# _________________________________________________________________

# %%
# make a embedding fx
def make_emmbedding():
    inp = Input(shape=(105, 105, 3), name="input_image")
    
    # block-1
    c1 = Conv2D(64, (10, 10), activation='relu')(inp)
    m1 = MaxPooling2D(64, (2, 2), padding="same")(c1)
    
    # Block-2
    c2 = Conv2D(128, (7, 7), activation='relu')(m1)
    m2 = MaxPooling2D(64, (2, 2), padding='same')(c2)
    
    # Block-3
    c3 = Conv2D(128, (4, 4), activation ='relu')(m2)
    m3 = MaxPooling2D(64, (2, 2), padding='same')(c3)
    
    # Final-Block
    c4 = Conv2D(256, (4, 4), activation='relu')(m3)
    f1 = Flatten()(c4)
    d1 = Dense(4096, activation='sigmoid')(f1)
    
    return Model(inputs=[inp], outputs=[d1], name='embedding')

# %%
embedding = make_emmbedding()
embedding.summary()
# Out:
# Model: "embedding"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_image (InputLayer)    [(None, 105, 105, 3)]     0
#
#  conv2d_4 (Conv2D)           (None, 96, 96, 64)        19264
#
#  max_pooling2d_3 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 42, 42, 128)       401536
#
#  max_pooling2d_4 (MaxPooling  (None, 21, 21, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 128)       262272
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 128)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)         524544
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_1 (Dense)             (None, 4096)              37752832
#
# =================================================================
# Total params: 38,960,448
# Trainable params: 38,960,448
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.2 Build Distance Layer

# %%
# L1 distance class , note- we have imported "Layer" from keras
class L1_dist(Layer):
    def __init__(self, **kwargs):
        super().__init__()
        
    # similarity calculation        
    def cal(self, input_embedding, validation_embedding):
        return tf.math.abs(input_embedding - validation_embedding)

# %%
l1 = L1_dist()

# %%
# we will define it later
# l1(anchor_embedding, validation_embedding)

# %% [markdown]
# ### 4.3 Make Siamese Model

# %%
input_image = Input(name='input_img', shape=(105, 105, 3))
validation_image = Input(name='validation_img', shape=(105, 105, 3))

# %%
inp_embedding = embedding(input_image)
val_embedding = embedding(validation_image)

# %%
siamese_layer = L1_dist()

# %%
distances = siamese_layer(inp_embedding, val_embedding)

# %%
classifier = Dense(1, activation='sigmoid')(distances)
classifier
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_2')>

# %%
siamese_network = Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')

# %%
siamese_network.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_img (InputLayer)         [(None, 105, 105, 3  0           []
#                                 )]
#
#  validation_img (InputLayer)    [(None, 105, 105, 3  0           []
#                                 )]
#
#  embedding (Functional)         (None, 4096)         38960448    ['input_img[0][0]',
#                                                                   'validation_img[0][0]']
#
#  l1_dist_1 (L1_dist)            (None, 4096)         0           ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  dense_2 (Dense)                (None, 1)            4097        ['l1_dist_1[0][0]']
#
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# make a siamese model fx
def make_siamese_model():
    # anchor input
    input_image = Input(name='input_img', shape=(105,105,3))
    
    # validation input
    vaidation_image = Input(name='validation_img', shape=(105, 105, 3))
    
    # combine
    siamese_layer = L1_dist()
    siamese_layer._name = 'distance'
    distances = siamese_layer(embedding(input_image), embedding(validation_image))
    
    # classification layer
    classifier = Dense(1, activation='sigmoid')(distances)
    return Model(inputs=[input_image, validation_image], outputs=classifier, name='SiameseNetwork')

# %%
siamese_model = make_siamese_model()
siamese_model.summary()
# Out:
# Model: "SiameseNetwork"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_img (InputLayer)         [(None, 105, 105, 3  0           []
#                                 )]
#
#  validation_img (InputLayer)    [(None, 105, 105, 3  0           []
#                                 )]
#
#  embedding (Functional)         (None, 4096)         38960448    ['input_img[0][0]',
#                                                                   'validation_img[0][0]']
#
#  distance (L1_dist)             (None, 4096)         0           ['embedding[2][0]',
#                                                                   'embedding[3][0]']
#
#  dense_3 (Dense)                (None, 1)            4097        ['distance[0][0]']
#
# ==================================================================================================
# Total params: 38,964,545
# Trainable params: 38,964,545
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Training

# %% [markdown]
# ### 5.1 Setup Loss and Optimizer

# %%
binary_cross_loss = tf.losses.BinaryCrossentropy()

# %%
optm = tf.keras.optimizers.Adam(1e-4) # set to 0.0001

# %% [markdown]
# ### 5.2 Establish Checkpoints

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, 'ckpt')
checkpoint = tf.train.Checkpoint(opt=optm, siamese_model=siamese_model)

# %% [markdown]
# ### 5.3 Build Train Step Function

# %%
test_batch = train_data.as_numpy_iterator()

# %%
batch_1 = test_batch.next()

# %%
X = batch_1[:2]

# %%
y = batch_1[2]

# %%
y  #len(y)
# Out:
# array([1., 1., 1.], dtype=float32)

# %%
@tf.function # compiles a function into a callable Tensorflow graph
def train_step(batch):
    
    # Record all of our operations automatic defferentiation
    with tf.GradientTape() as tape:     
        # Get anchor and positive/negative image
        X = batch[:2]
        # Get label
        y = batch[2]
        
        # Forward pass
        y_pred = siamese_model(X, training=True)
        # Calculate loss
        loss = binary_cross_loss(y, y_pred)
    print(loss)
        
    # Calculate gradients
    grad = tape.gradient(loss, siamese_model.trainable_variables)
    
    # Calculate updated weights and apply to siamese model
    optm.apply_gradients(zip(grad, siamese_model.trainable_variables))
        
    # Return loss
    return loss

# %% [markdown]
# ### 5.4 Build Training Loop

# %%
# Import metric calculations
from tensorflow.keras.metrics import Precision, Recall

# %%
def train(data, epochs):
    # Loop through epochs
    for epoch in range(1, epochs+1):
        print('\n Epoch {}/{}'.format(epoch, epochs))
        progbar = tf.keras.utils.Progbar(len(data))
        
        # Creating a metric object 
        r = Recall()
        p = Precision()
        
        # Loop through each batch
        for indx, batch in enumerate(data):
            # Run train step here
            loss = train_step(batch)
            y_pre = siamese_model.predict(batch[:2])
            r.update_state(batch[2], y_pre)
            p.update_state(batch[2], y_pre) 
            progbar.update(indx+1)
        print("Loss=> ",loss.numpy(), "Recall=> ",r.result().numpy(), "Precision=> ",p.result().numpy())
        
        # Save checkpoints
        if epoch % 10 == 0: 
            checkpoint.save(file_prefix=checkpoint_prefix)

# %% [markdown]
# ### 5.5 Train the Model

# %%
epochs = 10

# %%
train(train_data, epochs)
# Out:
#  Epoch 1/10
# Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# Tensor("binary_crossentropy/weighted_loss/value:0", shape=(), dtype=float32)
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 9s 9s/step
# Loss=>  0.63730437 Recall=>  0.0 Precision=>  0.0
#
#  Epoch 2/10
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.71463203 Recall=>  1.0 Precision=>  1.0
#
#  Epoch 3/10
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.6521546 Recall=>  1.0 Precision=>  0.6666667
#
#  Epoch 4/10
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.7453148 Recall=>  1.0 Precision=>  0.6666667
#
#  Epoch 5/10
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 7s 7s/step
# Loss=>  1.773034 Recall=>  0.0 Precision=>  0.0
#
#  Epoch 6/10
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.8517024 Recall=>  0.0 Precision=>  0.0
#
#  Epoch 7/10
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.70286006 Recall=>  0.0 Precision=>  0.0
#
#  Epoch 8/10
# 1/1 [==============================] - 0s 469ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.6582621 Recall=>  0.0 Precision=>  0.0
#
#  Epoch 9/10
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.78469855 Recall=>  0.0 Precision=>  0.0
#
#  Epoch 10/10
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 6s 6s/step
# Loss=>  0.6414005 Recall=>  0.0 Precision=>  0.0

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ### 6.1 Make Predictions

# %%
test_input, test_val, y_true = test_data.as_numpy_iterator().next()

# %%
y_predd = siamese_model.predict([test_input, test_val])
# Out:
# 1/1 [==============================] - 0s 468ms/step

# %%
[ 1 if prediction > 0.6 else 0 for prediction in y_predd]
# Out:
# [0, 0, 0]

# %%
y_true
# Out:
# array([0., 1., 0.], dtype=float32)

# %% [markdown]
# ### 6.2 Calculate Metrics

# %%
# recall matrix
mat = Recall()

mat.update_state(y_true, y_predd)

mat.result().numpy()
# Out:
# 0.0

# %%
# precision matrix
mtx = Precision()
mtx.update_state(y_true, y_predd)

mtx.result().numpy()
# Out:
# 0.0

# %%
# both matrices
r = Recall()
p = Precision()

for test_input,test_val, y_true in test_data.as_numpy_iterator():
    y_pred = siamese_model.predict([test_input, test_val])
    r.update_state(y_true, y_pred)
    p.update_state(y_true, y_pred)
    
print("Recall score is: ", r.result().numpy(), "Precision score is: ", p.result().numpy())
# Out:
# 1/1 [==============================] - 0s 457ms/step
# Recall score is:  0.0 Precision score is:  0.0

# %% [markdown]
# ### 6.3 Create Result visualization

# %%
plt.figure(figsize=(10, 8))
plt.subplot(1, 2, 1)
plt.imshow(test_input[0])
plt.subplot(1, 2, 2)
plt.imshow(test_val[0])
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
# Save weights
siamese_model.save('siamese_network_v2.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Reload model 
siamese_model = tf.keras.models.load_model('siamese_network_v2.h5', 
                                   custom_objects={'L1_dist':L1_dist, 'BinaryCrossentropy':tf.losses.BinaryCrossentropy})
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_saved_model('/home/sangramdh/jupyter/Siamese_Architecture/siamese_network_v2.h5')
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [4], line 2
#       1 import tensorflow as tf
# ----> 2 converter = tf.lite.TFLiteConverter.from_saved_model('/home/sangramdh/jupyter/Siamese_Architecture/siamese_network_v2.h5')
#       3 converter.optimizations = [tf.lite.Optimize.DEFAULT]
#       4 tflite_quant_model = converter.convert()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/lite/python/lite.py:1792, in TFLiteConverterV2.from_saved_model(cls, saved_model_dir, signature_keys, tags)
#    1789   tags = set([_tag_constants.SERVING])
#    1791 with context.eager_mode():
# -> 1792   saved_model = _load(saved_model_dir, tags)
#    1793 if not signature_keys:
#    1794   signature_keys = saved_model.signatures
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:828, in load(export_dir, tags, options)
#     826 if isinstance(export_dir, os.PathLike):
#     827   export_dir = os.fspath(export_dir)
# --> 828 result = load_partial(export_dir, None, tags, options)["root"]
#     829 return result
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:933, in load_partial(export_dir, filters, tags, options)
#     928 if tags is not None and not isinstance(tags, set):
#     929   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
#     930   # sequences for nest.flatten, so we put those through as-is.
#     931   tags = nest.flatten(tags)
#     932 saved_model_proto, debug_info = (
# --> 933     loader_impl.parse_saved_model_with_debug_info(export_dir))
#     935 if (len(saved_model_proto.meta_graphs) == 1 and
#     936     saved_model_proto.meta_graphs[0].HasField("object_graph_def")):
#     937   metrics.IncrementReadApi(_LOAD_V2_LABEL)
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/loader_impl.py:57, in parse_saved_model_with_debug_info(export_dir)
#      44 def parse_saved_model_with_debug_info(export_dir):
#      45   """Reads the savedmodel as well as the graph debug info.
#      46
#      47   Args:
#    (...)
#      55     parsed. Missing graph debug info file is fine.
#      56   """
# ---> 57   saved_model = parse_saved_model(export_dir)
#      59   debug_info_path = file_io.join(
#      60       saved_model_utils.get_debug_dir(export_dir),
#      61       constants.DEBUG_INFO_FILENAME_PB)
#      62   debug_info = graph_debug_info_pb2.GraphDebugInfo()
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/saved_model/loader_impl.py:115, in parse_saved_model(export_dir)
#     113     raise IOError(f"Cannot parse file {path_to_pbtxt}: {str(e)}.")
#     114 else:
# --> 115   raise IOError(
#     116       f"SavedModel file does not exist at: {export_dir}{os.path.sep}"
#     117       f"{{{constants.SAVED_MODEL_FILENAME_PBTXT}|"
#     118       f"{constants.SAVED_MODEL_FILENAME_PB}}}")
#
# OSError: SavedModel file does not exist at: /home/sangramdh/jupyter/Siamese_Architecture/siamese_network_v2.h5/{saved_model.pbtxt|saved_model.pb}

# %%
# predictions with loaded model
siamese_model.predict([test_input, test_val])
# Out:
# 1/1 [==============================] - 0s 463ms/step
# array([[0.6000734 ],
#        [0.6000426 ],
#        [0.6001176 ],
#        [0.59962934],
#        [0.5998098 ],
#        [0.6002694 ],
#        [0.6004321 ],
#        [0.6000715 ],
#        [0.5992563 ],
#        [0.59993   ],
#        [0.60007995],
#        [0.6002757 ]], dtype=float32)

# %% [markdown]
# # 8. Real Time Test

# %%
def verify(model, detection_threshold, verification_threshold):
    # Build results array
    results = []
    for image in os.listdir(os.path.join('/home/sangramdh/jupyter/Siamese_Architecture/app/application_data/', '/home/sangramdh/jupyter/Siamese_Architecture/app/application_data/verification_images/')):
        input_img = preprocess(os.path.join('/home/sangramdh/jupyter/Siamese_Architecture/app/application_data/', '/home/sangramdh/jupyter/Siamese_Architecture/app/application_data/input_image/', 'input_image.jpg'))
        validation_img = preprocess(os.path.join('/home/sangramdh/jupyter/Siamese_Architecture/app/application_data/', '/home/sangramdh/jupyter/Siamese_Architecture/app/application_data/verification_images/', image))
        
        # Make Predictions 
        result = model.predict(list(np.expand_dims([input_img, validation_img], axis=1)))
        results.append(result)
    
    # Detection Threshold: Metric above which a prediciton is considered positive 
    detection = np.sum(np.array(results) > detection_threshold)
    
    # Verification Threshold: Proportion of positive predictions / total positive samples 
    verification = detection / len(os.listdir(os.path.join('application_data', 'verification_images'))) 
    verified = verification > verification_threshold
    
    return results, verified

# %% [markdown]
# ### 8.1 From Camera

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    frame = frame[120:120+250,200:200+250, :]
    
    cv2.imshow('Verification', frame)
    
    # Verification trigger
    if cv2.waitKey(10) & 0xFF == ord('v'):
        # Save input image to application_data/input_image folder 
#         hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
#         h, s, v = cv2.split(hsv)

#         lim = 255 - 10
#         v[v > lim] = 255
#         v[v <= lim] -= 10
        
#         final_hsv = cv2.merge((h, s, v))
#         img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)

        cv2.imwrite(os.path.join('application_data', 'input_image', 'input_image.jpg'), frame)
        # Run verification
        results, verified = verify(siamese_model, 0.5, 0.5)
        print(verified)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 cap = cv2.VideoCapture(0)
#       2 while cap.isOpened():
#       3     ret, frame = cap.read()
#
# NameError: name 'cv2' is not defined

# %%
np.sum(np.squeeze(results) > 0.9)

# %%
results

# %%
pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:02
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 14.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 18.9 MB/s eta 0:00:0031m22.2 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /home/sangramdh/.local/lib/python3.10/site-packages (from torch) (4.4.0)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 7.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (59.6.0)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.1+cu117'

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.cuda.get_device_name(0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 torch.cuda.get_device_name(0)
#
# File ~/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:341, in get_device_name(device)
#     329 def get_device_name(device: Optional[_device_t] = None) -> str:
#     330     r"""Gets the name of a device.
#     331
#     332     Args:
#    (...)
#     339         str: the name of the device
#     340     """
# --> 341     return get_device_properties(device).name
#
# File ~/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:371, in get_device_properties(device)
#     361 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     362     r"""Gets the properties of a device.
#     363
#     364     Args:
#    (...)
#     369         _CudaDeviceProperties: the properties of the device
#     370     """
# --> 371     _lazy_init()  # will define _get_device_properties
#     372     device = _get_device_index(device, optional=True)
#     373     if device < 0 or device >= device_count():
#
# File ~/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:229, in _lazy_init()
#     227 if 'CUDA_MODULE_LOADING' not in os.environ:
#     228     os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
# --> 229 torch._C._cuda_init()
#     230 # Some of the queued calls may reentrantly call _lazy_init();
#     231 # we need to just return without initializing in that case.
#     232 # However, we must not let any *other* threads in!
#     233 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
